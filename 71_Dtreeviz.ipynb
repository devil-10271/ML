# %%
# !pip install dtreeviz

import dtreeviz 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_iris,fetch_california_housing
from sklearn.model_selection import train_test_split
import graphviz.backend as be

from sklearn.datasets import *
# from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG

data= load_iris()

df1 = pd.DataFrame(data.data,columns=data.feature_names)

df1["taget"] = data.target

x_train,x_test,y_train,y_test  = train_test_split(df1.drop("taget",axis=1),df1.taget,test_size=0.2)

DTC =DecisionTreeClassifier()

DTC.fit(x_train,y_train)

from sklearn.tree import plot_tree

plot_tree(DTC)


viz = dtreeviz.model(DTC, x_train, y_train, target_name="target", feature_names=data.feature_names)
viz.view()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
# ...
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:88, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      87 try:
# ---> 88     proc.check_returncode()
#      89 except subprocess.CalledProcessError as e:
#
# File ~\anaconda3\Lib\subprocess.py:508, in CompletedProcess.check_returncode(self)
#     507 if self.returncode:
# --> 508     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     509                              self.stderr)
#
# ...
