# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("./CSVs/Titanic-Dataset.csv")

# %%
df.sample(7)
# Out:
#      PassengerId  Survived  Pclass  \
# 719          720         0       3
# 811          812         0       3
# 416          417         1       2
# 788          789         1       3
# 801          802         1       2
# 528          529         0       3
# 34            35         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 719                     Johnson, Mr. Malkolm Joackim    male  33.0      0
# 811                                Lester, Mr. James    male  39.0      0
# 416  Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
# 788                       Dean, Master. Bertram Vere    male   1.0      1
# 801      Collyer, Mrs. Harvey (Charlotte Annie Tate)  female  31.0      1
# 528                        Salonen, Mr. Johan Werner    male  39.0      0
# 34                           Meyer, Mr. Edgar Joseph    male  28.0      1
#
#      Parch      Ticket     Fare Cabin Embarked
# 719      0      347062   7.7750   NaN        S
# 811      0   A/4 48871  24.1500   NaN        S
# 416      1       28220  32.5000   NaN        S
# 788      2   C.A. 2315  20.5750   NaN        S
# 801      1  C.A. 31921  26.2500   NaN        S
# 528      0     3101296   7.9250   NaN        S
# 34       0    PC 17604  82.1708   NaN        C

# %% [markdown]
# # 1. Catogorical data

# %% [markdown]
# ## count plot on target

# %%
sns.countplot(x=df["Survived"])
df["Survived"].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [markdown]
# ## piechart

# %%
df['Pclass'].value_counts().plot(kind="pie",autopct="%.2f")
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %% [markdown]
# # 2. Numerical Data

# %% [markdown]
# ## Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Distplot (with kde(kernel density estimation) with pdf(probablity density function))

# %%
sns.distplot(df.Age,kde=True)
# Out:
# C:\Users\Admi\AppData\Local\Temp\ipykernel_16076\843646407.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.Age,kde=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## box plot for Outliers

# %%
sns.boxplot(df['Age'])
df['Age'].median()
# Out:
# 28.0
