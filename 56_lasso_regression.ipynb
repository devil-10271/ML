# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression,Lasso
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
x,y=make_regression(n_samples=100,n_features=1,n_targets=1,n_informative=2,noise=20)

# %%
plt.scatter(x=x,y=y)

# %%
reg = LinearRegression()

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.8)

# %%
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_ ,reg.intercept_
# Out:
# (array([33.16718025]), np.float64(-2.356416890271379))

# %%
list1 = [0.001,0.01,0.1,1,10,100,1000]

# %%
plt.scatter(x_train,y_train,c="red")
for i in list1:
    lass = Lasso(alpha=i)
    lass.fit(x_train,y_train)

    plt.plot(x_test,lass.predict(x_test),label = "alphas {}".format(i))
plt.legend()
plt.show()
