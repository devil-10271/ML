# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X,Y= make_regression(n_samples=1000,n_features=1,n_targets=1,noise=40,random_state=10,n_informative=1)

# %%
X.shape, Y.shape
# Out:
# ((1000, 1), (1000,))

# %%
plt.scatter(x=X,y=Y)
plt.show()

# %%
lr= LinearRegression()
x_train,x_test,y_train,y_test = train_test_split(X,Y,random_state=42,test_size=0.15)

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_ ,lr.coef_
# Out:
# (np.float64(0.7497900488957844), array([50.04786767]))

# %%
class meraLR : 
    def __init__(self,learning_rate,epochs):
        self.m = 100    
        self.b = -120
        self.lr = learning_rate
        self.epo = epochs

    def fit(self,X,Y):
        for i in range(self.epo):
            loss_slope_b = -2 * np.sum(Y - self.m*X.ravel() - self.b)
            loss_slope_m = -2 * np.sum((Y - self.m*X.ravel() - self.b) * X.ravel())
            self.m = self.m - (self.lr * loss_slope_m)
            self.b = self.b - (self.lr * loss_slope_b) 
        print(self.m,self.b)


    def predict(self,x_tr):
        y = self.m *x_tr + self.b
        return y

# %%
lr1 = meraLR(0.0001,1000)

# %%
lr1.fit(x_train,y_train)
print(lr.coef_, lr.intercept_)
# Out:
# 50.04786767182523 0.7497900488957858
# [50.04786767] 0.7497900488957844

# %%
pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,pred)
pred1 = lr1.predict(x_test)
r2_score(y_test,pred1)
# Out:
# 0.6280020695501507
