# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as ex
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv("diabetes.csv")

# %%
df_cols= df.columns
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
features = [col for col in df.columns if col != 'Outcome']

# Create and show a scatter plot for each consecutive pair of features
for i in range(len(features) - 1):
    x_col = features[i]
    y_col = features[i + 1]
    
    fig = px.scatter(
        df,
        x=x_col,
        y=y_col,
        color='Outcome',
        title=f'{x_col} vs {y_col} (colored by Outcome)',
        labels={'Outcome': 'Diabetes Outcome'},
        color_continuous_scale='Viridis',  # or use 'Rainbow' for discrete? Outcome is numeric 0/1
        hover_data=df.columns.tolist()     # show all values on hover
    )
    # Improve discrete color mapping (0 and 1)
    fig.update_traces(marker=dict(size=8, opacity=0.7))
    fig.update_layout(
        xaxis_title=x_col,
        yaxis_title=y_col,
        legend_title_text='Outcome',
        template='plotly_white'
    )
    fig.show()

# %%
# !pip install ydata_profiling
from ydata_profiling import ProfileReport

# Generate the profiling report with 'Outcome' as the target column
profile = ProfileReport(df)

# Display the report (opens in browser)
profile.to_file("diabetes_report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
