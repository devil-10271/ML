# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("./CSVs/placement_test.csv")

# %%
df_cols=df.columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961240             32.225000     0.489000
# std       0.615898             19.130822     0.500129
# min       4.890000              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       9.120000            100.000000     1.000000

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# Plot 'iq' on the first subplot (index 0)
sns.histplot(df.placement_exam_marks, kde=True, ax=axes[0])
axes[0].set_title('IQ Distribution') # Optional: Set title for clarity

# Plot 'cgpa' on the second subplot (index 1)
sns.histplot(df.cgpa, kde=True, ax=axes[1])
axes[1].set_title('CGPA Distribution') # Optional: Set title for clarity
# Out:
# Text(0.5, 1.0, 'CGPA Distribution')

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961240             32.225000     0.489000
# std       0.615898             19.130822     0.500129
# min       4.890000              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       9.120000            100.000000     1.000000

# %%
print("Lower Limit : ",df.cgpa.mean() - (3*df.cgpa.std()))
print("Upper Limit : ",df.cgpa.mean() + (3*df.cgpa.std()))
# Out:
# Lower Limit :  5.113546374602832
# Upper Limit :  8.808933625397168

# %%
df[(df['cgpa'] > 8.80) | (df['cgpa'] < 5.11)]
# Out:
#      cgpa  placement_exam_marks  placed
# 485  4.92                  44.0       1
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 999  4.90                  10.0       1

# %% [markdown]
# # Trimming

# %%
df1 = df[(df['cgpa'] < 8.80) & (df['cgpa'] > 5.11)]

# %%
df1.shape
# Out:
# (995, 3)

# %% [markdown]
# # Capping

# %%
lower_limit = df.cgpa.mean() - (3*df.cgpa.std())
upper_limit = df.cgpa.mean() + (3*df.cgpa.std())

# %%
df['cgpa']=np.where(df.cgpa < lower_limit, lower_limit , np.where(df.cgpa > upper_limit,upper_limit,df.cgpa))

# %%
# df=pd.DataFrame(columns=df_cols)

# %%
df.describe()
# Out:
#               cgpa  placement_exam_marks       placed
# count  1000.000000           1000.000000  1000.000000
# mean      6.961499             32.225000     0.489000
# std       0.612688             19.130822     0.500129
# min       5.113546              0.000000     0.000000
# 25%       6.550000             17.000000     0.000000
# 50%       6.960000             28.000000     0.000000
# 75%       7.370000             44.000000     1.000000
# max       8.808934            100.000000     1.000000
